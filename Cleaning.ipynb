# %%
print('Hello world!')
# Out:
# Hello world!

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alex', 'Maria'],
    'Age': [35, 45],
    'City': ['Moscow', 'SPb']
}
df = pd.DataFrame(data)
print('Starting DataFrame:')
print(df)

filtred_df = df[df['Age']>40]

df['Salary'] = [300000, 240000]

print('\nNewDataFrame wiht a salary:')
print(df)
# Out:
# Starting DataFrame:
#     Name  Age    City
# 0   Alex   35  Moscow
# 1  Maria   45     SPb
#
# NewDataFrame wiht a salary:
#     Name  Age    City  Salary
# 0   Alex   35  Moscow  300000
# 1  Maria   45     SPb  240000

# %%
data = {
    'Name': ['Alex', 'Maria'],
    'Age': [35, 45],
    'City': ['Moscow', 'SPb']
}
df = pd.DataFrame(data)
print('Starting DataFrame:')
print(df)

df['Salary'] = [300000, 240000]

print('\nNewDataFrame wiht a salary:')
print(df)

filtred_df = df[df['Age']>20]
# Out:
# Starting DataFrame:
#     Name  Age    City
# 0   Alex   35  Moscow
# 1  Maria   45     SPb
#
# NewDataFrame wiht a salary:
#     Name  Age    City  Salary
# 0   Alex   35  Moscow  300000
# 1  Maria   45     SPb  240000

# %%
namelist = ['wub_wub', 'theelous3', 'RubyPinch', 'go|dfish', 'Nitori']

name = input("Enter your name: ")
if name in namelist:
    print("I know you!")
else:
    print("Sorry, I don't know who you are :(")
# Out:
# Enter your name:  Nitori
# I know you!

# %%
namelist = ['wub_wub', 'RubyPinch', 'go|dfish', 'Nitori']
namelist.append('pb122')
if 'pb122' in namelist:
    print("Now I know pb122!")
# Out:
# Now I know pb122!

# %%
print("Hello!")
name = input("Enter your name: ")
print(f"Your name is " + name + ".")
# Out:
# Hello!
# Enter your name:  HJJJK
# Your name is HJJJK.

# %%
namelist = ['wub_wub', 'RubyPinch', 'go|dfish', 'Nitori']
namelist.append('theelous3')
n = input("Enter your name: ")
if n in namelist:
    print("I know you!")
else:
    print("I don't know you.")
# Out:
# Enter your name:  hghghgkg
# I don't know you.

# %%
#загрузка df
df = pd.read_excel(r"\\kosmarket.local\dfs\БИГ\Данные BI\Максим\Plan_Fact_Report_Сетевой Ритейл\Fact_report_dashboard (XLSX).xlsx")
df.head(25)
# Out:
#                                     Unnamed: 0  Unnamed: 1  \
# 0   Валовая прибыль предприятия %ВалютаОтчета%         NaN
# 1                                          NaN         NaN
# 2                                   Параметры:         NaN
# 3                                          NaN         NaN
# 4                                          NaN         NaN
# 5                                          NaN         NaN
# 6                                       Отбор:         NaN
# 7                                          NaN         NaN
# 8                           Контрагент.Партнер         NaN
# 9                                          NaN         NaN
# 10                                   Тандер АО         NaN
# 11                                   Тандер АО         NaN
# 12                                   Тандер АО         NaN
# 13                                   Тандер АО         NaN
# 14                                   Тандер АО         NaN
# ...

# %%
#удаление первых 8 строк 
df = df.drop(index=range(8)).reset_index(drop=True)

df.head(15)
# Out:
#             Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0   Контрагент.Партнер         NaN        NaN
# 1                  NaN         NaN        NaN
# 2            Тандер АО         NaN        NaN
# 3            Тандер АО         NaN        NaN
# 4            Тандер АО         NaN        NaN
# 5            Тандер АО         NaN        NaN
# 6            Тандер АО         NaN        NaN
# 7            Тандер АО         NaN        NaN
# 8            Тандер АО         NaN        NaN
# 9            Тандер АО         NaN        NaN
# 10           Тандер АО         NaN        NaN
# 11           Тандер АО         NaN        NaN
# 12           Тандер АО         NaN        NaN
# 13           Тандер АО         NaN        NaN
# 14           Тандер АО         NaN        NaN
#
#                                     Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   Номенклатура.Объединенная номенклатура.Код  01.01.2024         NaN
# 1                                          NaN  Количество         NaN
# ...

# %%
#установка строки 0 как заголовка
df.columns = df.iloc[0]
df = df[1:]

# %%
df.head(5)
# Out:
# 0 Контрагент.Партнер  0.0  0 Номенклатура.Объединенная номенклатура.Код  \
# 1                  0  0.0  0                                          0
# 2          Тандер АО  0.0  0                                БГ-00030710
# 3          Тандер АО  0.0  0                                БГ-00023379
# 4          Тандер АО  0.0  0                                БГ-00018385
# 5          Тандер АО  0.0  0                                БГ-00023380
#
# 0  01.01.2024  0.0  01.02.2024  0.0  01.03.2024  01.04.2024  01.05.2024  \
# 1  Количество  0.0  Количество  0.0  Количество  Количество  Количество
# 2        8696  0.0       34176  0.0       16992       45304       17856
# 3       12544  0.0       14192  0.0       11628       11448         216
# 4       16808  0.0        9320  0.0       19248         840       42168
# 5       12600  0.0       12960  0.0       11318       10206        1620
#
# 0  01.06.2024  01.07.2024  01.08.2024  01.09.2024  01.10.2024  01.11.2024  \
# ...

# %%
#замена всех пропусков нулями
df = df.fillna(0)
df.head(5)
# Out:
# 0 Контрагент.Партнер  0.0  0 Номенклатура.Объединенная номенклатура.Код  \
# 1                  0  0.0  0                                          0
# 2          Тандер АО  0.0  0                                БГ-00030710
# 3          Тандер АО  0.0  0                                БГ-00023379
# 4          Тандер АО  0.0  0                                БГ-00018385
# 5          Тандер АО  0.0  0                                БГ-00023380
#
# 0  01.01.2024  0.0  01.02.2024  0.0  01.03.2024  01.04.2024  01.05.2024  \
# 1  Количество  0.0  Количество  0.0  Количество  Количество  Количество
# 2        8696  0.0       34176  0.0       16992       45304       17856
# 3       12544  0.0       14192  0.0       11628       11448         216
# 4       16808  0.0        9320  0.0       19248         840       42168
# 5       12600  0.0       12960  0.0       11318       10206        1620
#
# 0  01.06.2024  01.07.2024  01.08.2024  01.09.2024  01.10.2024  01.11.2024  \
# ...

# %%
#удаление колонок с названием ноль
df = df.loc[:, df.columns !=0]

# %%
df.head(5)
# Out:
# 0 Контрагент.Партнер Номенклатура.Объединенная номенклатура.Код  01.01.2024  \
# 1                  0                                          0  Количество
# 2          Тандер АО                                БГ-00030710        8696
# 3          Тандер АО                                БГ-00023379       12544
# 4          Тандер АО                                БГ-00018385       16808
# 5          Тандер АО                                БГ-00023380       12600
#
# 0  01.02.2024  01.03.2024  01.04.2024  01.05.2024  01.06.2024  01.07.2024  \
# 1  Количество  Количество  Количество  Количество  Количество  Количество
# 2       34176       16992       45304       17856       27456       49344
# 3       14192       11628       11448         216       10152       16416
# 4        9320       19248         840       42168       27720       10416
# 5       12960       11318       10206        1620        6492       19242
#
# ...

# %%
df1 = df

# %%
df1.head(5)
# Out:
# 0 Контрагент.Партнер Номенклатура.Объединенная номенклатура.Код  01.01.2024  \
# 1                  0                                          0  Количество
# 2          Тандер АО                                БГ-00030710        8696
# 3          Тандер АО                                БГ-00023379       12544
# 4          Тандер АО                                БГ-00018385       16808
# 5          Тандер АО                                БГ-00023380       12600
#
# 0  01.02.2024  01.03.2024  01.04.2024  01.05.2024  01.06.2024  01.07.2024  \
# 1  Количество  Количество  Количество  Количество  Количество  Количество
# 2       34176       16992       45304       17856       27456       49344
# 3       14192       11628       11448         216       10152       16416
# 4        9320       19248         840       42168       27720       10416
# 5       12960       11318       10206        1620        6492       19242
#
# ...

# %%
#удаление строки с индексом 1 (не нужной)
df1 = df1.drop(index = 1)
#сброс индексов
df1.reset_index(drop=True, inplace=True)

# %%
df1.head(5)
# Out:
# 0 Контрагент.Партнер Номенклатура.Объединенная номенклатура.Код 01.01.2024  \
# 0          Тандер АО                                БГ-00030710       8696
# 1          Тандер АО                                БГ-00023379      12544
# 2          Тандер АО                                БГ-00018385      16808
# 3          Тандер АО                                БГ-00023380      12600
# 4          Тандер АО                                БГ-00023381      13848
#
# 0 01.02.2024 01.03.2024 01.04.2024 01.05.2024 01.06.2024 01.07.2024  \
# 0      34176      16992      45304      17856      27456      49344
# 1      14192      11628      11448        216      10152      16416
# 2       9320      19248        840      42168      27720      10416
# 3      12960      11318      10206       1620       6492      19242
# 4      11568      11352      11016       1512       6912       5316
#
# 0 01.08.2024 01.09.2024 01.10.2024 01.11.2024 01.12.2024 01.01.2025 01.02.2025
# ...

# %%
#удаляем дубликаты
df1 = df1.drop_duplicates()

# %%
df1.tail(5)
# Out:
# 0    Контрагент.Партнер Номенклатура.Объединенная номенклатура.Код 01.01.2024  \
# 1493        БЭСТЛЕР ООО                                БГ-00019959          0
# 1494        БЭСТЛЕР ООО                                БГ-00019961          0
# 1495        БЭСТЛЕР ООО                                БГ-00024299          0
# 1496        БЭСТЛЕР ООО                                БГ-00008449          0
# 1497              Итого                                          0    1146853
#
# 0    01.02.2024 01.03.2024 01.04.2024 01.05.2024 01.06.2024 01.07.2024  \
# 1493       -102          0          0          0          0          0
# 1494       -118          0          0          0          0          0
# 1495       -155          0          0          0          0          0
# 1496       -211          0          0          0          0          0
# 1497    1198209    1080066    1471109    1496162    1433403    2045042
#
# ...

# %%
df1 = df1.drop(index = 1497)

# %%
df1.tail(5)
# Out:
# 0    Контрагент.Партнер Номенклатура.Объединенная номенклатура.Код 01.01.2024  \
# 1492        БЭСТЛЕР ООО                                БГ-00030732          0
# 1493        БЭСТЛЕР ООО                                БГ-00019959          0
# 1494        БЭСТЛЕР ООО                                БГ-00019961          0
# 1495        БЭСТЛЕР ООО                                БГ-00024299          0
# 1496        БЭСТЛЕР ООО                                БГ-00008449          0
#
# 0    01.02.2024 01.03.2024 01.04.2024 01.05.2024 01.06.2024 01.07.2024  \
# 1492       -217          0          0          0          0          0
# 1493       -102          0          0          0          0          0
# 1494       -118          0          0          0          0          0
# 1495       -155          0          0          0          0          0
# 1496       -211          0          0          0          0          0
#
# ...
